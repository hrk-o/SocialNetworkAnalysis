# %%
import graph_lib as glib
import matplotlib.pyplot as plt
import japanize_matplotlib # 日本語
import math

lib = glib.graph_lib()

# %%
# 一次元格子(グラフ)

nnode = list() # ノード数
nedge = list() # エッジ数
avedegree = list() # 平均次数
avespl = list() # 平均最短経路長
diameter = list() # 直径
aveclust = list() # クラスタリング係数
checkavespl = list() #平均最短経路長(平均頂点間距離)確認用

for num in range(1,50):
    lib.one_dimensional_grid(num)
    nnode.append(lib.getnnode())# ノード数
    nedge.append(lib.getnedge())# エッジ数
    avedegree.append(lib.getavedegree())# 平均次数
    avespl.append(lib.getavespl())# 平均最短経路長
    diameter.append(lib.getdiameter())# 直径
    aveclust.append(lib.getaveclust())# クラスタリング係数
    checkavespl.append(lib.getnnode() / 3)# 平均最短経路長(平均頂点間距離)確認用

plt.figure(0)    
plt.plot(nnode, nedge, label="エッジ数")  
plt.plot(nnode, avedegree, label="平均次数")  
plt.plot(nnode, avespl, label="平均最短経路長")  
plt.plot(nnode, diameter, label="直径")  
plt.plot(nnode, aveclust, label="クラスタリング係数") 
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0)

plt.figure(1)
plt.plot(nnode, avespl, label="平均最短経路長")  
plt.plot(nnode, checkavespl, label="平均最短経路長(確認)")  
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0)

# %%
# 二次元正方格子(グラフ)

nnode = list() # ノード数
nedge = list() # エッジ数
avedegree = list() # 平均次数
avespl = list() # 平均最短経路長
diameter = list() # 直径
aveclust = list() # クラスタリング係数
checkavespl = list() #平均最短経路長(平均頂点間距離)確認用

for num in range(1,10):
    lib.two_dimensional_square_lattice(num)
    nnode.append(lib.getnnode())# ノード数
    nedge.append(lib.getnedge())# エッジ数
    avedegree.append(lib.getavedegree())# 平均次数
    avespl.append(lib.getavespl())# 平均最短経路長
    diameter.append(lib.getdiameter())# 直径
    aveclust.append(lib.getaveclust())# クラスタリング係数
    checkavespl.append(math.sqrt(lib.getnnode()))# 平均最短経路長(平均頂点間距離)確認用

plt.figure(0)    
plt.plot(nnode, nedge, label="エッジ数")  
plt.plot(nnode, avedegree, label="平均次数")  
plt.plot(nnode, avespl, label="平均最短経路長")  
plt.plot(nnode, diameter, label="直径")  
plt.plot(nnode, aveclust, label="クラスタリング係数") 
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0)

plt.figure(1)
plt.plot(nnode, avespl, label="平均最短経路長")  
plt.plot(nnode, checkavespl, label="平均最短経路長(確認)")  
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0)

# %%
# 三次元正方格子(グラフ)

nnode = list() # ノード数
nedge = list() # エッジ数
avedegree = list() # 平均次数
avespl = list() # 平均最短経路長
diameter = list() # 直径
aveclust = list() # クラスタリング係数
checkavespl = list() #平均最短経路長(平均頂点間距離)確認用

for num in range(1,10):
    lib.three_dimensional_square_lattice(num)
    nnode.append(lib.getnnode())# ノード数
    nedge.append(lib.getnedge())# エッジ数
    avedegree.append(lib.getavedegree())# 平均次数
    avespl.append(lib.getavespl())# 平均最短経路長
    diameter.append(lib.getdiameter())# 直径
    aveclust.append(lib.getaveclust())# クラスタリング係数
    checkavespl.append(math.pow(lib.getnnode(), 1.0/3.0))# 平均最短経路長(平均頂点間距離)確認用

plt.figure(0)    
plt.plot(nnode, nedge, label="エッジ数")  
plt.plot(nnode, avedegree, label="平均次数")  
plt.plot(nnode, avespl, label="平均最短経路長")  
plt.plot(nnode, diameter, label="直径")  
plt.plot(nnode, aveclust, label="クラスタリング係数") 
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0)

plt.figure(1)
plt.plot(nnode, avespl, label="平均最短経路長")  
plt.plot(nnode, checkavespl, label="平均最短経路長(確認)")  
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0)

# %%
# 二次元三角格子(グラフ)

nnode = list() # ノード数
nedge = list() # エッジ数
avedegree = list() # 平均次数
avespl = list() # 平均最短経路長
diameter = list() # 直径
aveclust = list() # クラスタリング係数
checkavespl = list() #平均最短経路長(平均頂点間距離)確認用

for num in range(1,10):
    lib.two_dimensional_triangular_lattice(num)
    nnode.append(lib.getnnode())# ノード数
    nedge.append(lib.getnedge())# エッジ数
    avedegree.append(lib.getavedegree())# 平均次数
    avespl.append(lib.getavespl())# 平均最短経路長
    diameter.append(lib.getdiameter())# 直径
    aveclust.append(lib.getaveclust())# クラスタリング係数
    checkavespl.append(math.pow(lib.getnnode(), 1.0/2.0))# 平均最短経路長(平均頂点間距離)確認用

plt.figure(0)    
plt.plot(nnode, nedge, label="エッジ数")  
plt.plot(nnode, avedegree, label="平均次数")  
plt.plot(nnode, avespl, label="平均最短経路長")  
plt.plot(nnode, diameter, label="直径")  
plt.plot(nnode, aveclust, label="クラスタリング係数") 
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0)

plt.figure(1)
plt.plot(nnode, avespl, label="平均最短経路長")  
plt.plot(nnode, checkavespl, label="平均最短経路長(確認)")  
plt.legend(bbox_to_anchor=(1, 1), loc='upper right', borderaxespad=0)

# %%
# 一次元格子
lib.one_dimensional_grid(4)
#print(lib.getnnode())# ノード数
#print(lib.getnedge())# エッジ数
#print(lib.getavedegree())# 平均次数
#print(lib.getavespl())# 平均最短経路長
#print(lib.getdiameter())# 直径
#print(lib.getaveclust())# クラスタリング係数
# Out:
# 4
# 3
# 1.5
# 1.6666666666666667
# 3
# 0.0
